# %%
# !pip install surprise
# Out:
# Requirement already satisfied: surprise in /opt/homebrew/lib/python3.10/site-packages (0.1)
# Requirement already satisfied: scikit-surprise in /opt/homebrew/lib/python3.10/site-packages (from surprise) (1.1.3)
# Requirement already satisfied: scipy>=1.3.2 in /opt/homebrew/lib/python3.10/site-packages (from scikit-surprise->surprise) (1.9.3)
# Requirement already satisfied: numpy>=1.17.3 in /opt/homebrew/lib/python3.10/site-packages (from scikit-surprise->surprise) (1.23.4)
# Requirement already satisfied: joblib>=1.0.0 in /opt/homebrew/lib/python3.10/site-packages (from scikit-surprise->surprise) (1.2.0)

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /opt/homebrew/lib/python3.10/site-packages (4.64.1)

# %%
# !pip install -upgrade IProgress
# Out:
# Usage:
#   pip install [options] <requirement specifier> [package-index-options] ...
#   pip install [options] -r <requirements file> [package-index-options] ...
#   pip install [options] [-e] <vcs project url> ...
#   pip install [options] [-e] <local project path> ...
#   pip install [options] <archive url/path> ...
#
# no such option: -u

# %%
# !pip install --upgrade IProgress
# Out:
# Requirement already satisfied: IProgress in /opt/homebrew/lib/python3.10/site-packages (0.4)
# Requirement already satisfied: six in /opt/homebrew/lib/python3.10/site-packages (from IProgress) (1.16.0)

# %%
from surprise import Dataset
from tqdm import tqdm_notebook
from surprise import Reader
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer

# %%
links = pd.read_csv('links.csv')
movies = pd.read_csv('movies.csv')
ratings = pd.read_csv('ratings.csv')
tags = pd.read_csv('tags.csv')

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings = ratings[:10000]
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
tags.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
def change_string(s):
    return ' '.join(s.replace(' ', '').replace('-', '').split('|'))
movie_genres = [change_string(g) for g in movies.genres.values]

# %%
ratings_and_tags = ratings.merge(tags, how='outer')

# %%
ratings_and_tags.head()
# Out:
#    userId  movieId  rating  timestamp  tag
# 0       1        1     4.0  964982703  NaN
# 1       1        3     4.0  964981247  NaN
# 2       1        6     4.0  964982224  NaN
# 3       1       47     5.0  964983815  NaN
# 4       1       50     5.0  964982931  NaN

# %%
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(movie_genres)
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

# %%
genres_dict = {}
for ind in tqdm_notebook(range(0,len(movies['movieId']))):
    genres_dict[movies['movieId'][ind]] = tfidf_transformer.transform(count_vect.transform([change_string(movies.genres[ind])]))
genres_dict
# Out:
# /var/folders/ll/sf8djrcj0ljd5cltbywtgm9w0000gn/T/ipykernel_9977/2753715477.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for ind in tqdm_notebook(range(0,len(movies['movieId']))):
#   0%|          | 0/9742 [00:00<?, ?it/s]
# {1: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 5 stored elements in Compressed Sparse Row format>,
#  2: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  3: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  4: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  5: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  6: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  7: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  8: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  9: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  10: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  11: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  12: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  13: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  14: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  15: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  16: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  17: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  18: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  19: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  20: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 5 stored elements in Compressed Sparse Row format>,
#  21: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  22: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 5 stored elements in Compressed Sparse Row format>,
#  23: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  24: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  25: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  26: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  27: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  28: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  29: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 5 stored elements in Compressed Sparse Row format>,
#  30: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  31: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  32: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  34: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  36: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  38: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  39: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  40: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  41: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  42: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  43: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  44: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  45: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  46: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  47: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  48: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 5 stored elements in Compressed Sparse Row format>,
#  49: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  50: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  52: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  53: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  54: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  55: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  57: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  58: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  60: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  61: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  62: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  63: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  64: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  65: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  66: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  68: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  69: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  70: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  71: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  72: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  73: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  74: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  75: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  76: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  77: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  78: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  79: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  80: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  81: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  82: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  83: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  85: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  86: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  87: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  88: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  89: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  92: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  93: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  94: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  95: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  96: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  97: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  99: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  100: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  101: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  102: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  103: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  104: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  105: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  106: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  107: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  108: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  110: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  111: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  112: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  113: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  116: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  117: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  118: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  119: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  121: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  122: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  123: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  125: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  126: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  128: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  129: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  132: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  135: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  137: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  140: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  141: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  144: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  145: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 5 stored elements in Compressed Sparse Row format>,
#  146: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  147: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  148: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  149: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  150: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  151: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  152: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  153: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  154: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  155: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  156: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  157: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  158: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  159: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  160: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  161: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  162: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  163: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  164: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  165: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  166: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  168: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  169: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  170: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  171: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  172: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  173: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  174: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  175: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  176: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  177: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  178: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  179: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  180: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  181: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  183: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  184: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  185: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  186: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  187: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  188: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  189: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  190: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  191: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  193: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  194: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  195: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  196: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  198: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 6 stored elements in Compressed Sparse Row format>,
#  199: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  201: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  202: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  203: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  204: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  205: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  206: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  207: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  208: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  209: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  210: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  211: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  212: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  213: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  214: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  215: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  216: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  217: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  218: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  219: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  220: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  222: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  223: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  224: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  225: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  227: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  228: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  229: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  230: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  231: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  232: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  233: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  234: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  235: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  236: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  237: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  238: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  239: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  240: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  241: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  242: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  243: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  246: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  247: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  248: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  249: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  250: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  251: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  252: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  253: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  254: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  255: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  256: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  257: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  258: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 5 stored elements in Compressed Sparse Row format>,
#  259: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  260: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  261: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  262: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  263: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  265: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  266: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  267: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  269: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  270: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  271: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  272: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  273: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  274: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  275: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  276: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  277: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  278: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  279: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  280: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  281: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  282: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  283: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  284: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  285: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  287: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  288: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  289: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  290: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  291: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  292: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  293: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  294: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  295: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  296: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  298: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  299: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  300: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  301: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  302: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  303: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  304: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  305: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  306: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  307: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  308: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  310: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  311: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  312: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  313: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  314: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  315: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  316: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  317: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  318: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  319: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  320: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  321: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  322: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  324: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  325: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  326: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  327: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  328: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  329: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  330: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  331: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  332: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  333: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  334: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  335: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  336: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  337: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  338: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  339: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  340: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  341: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  342: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  343: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  344: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  345: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  346: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  347: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  348: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  349: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  350: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  351: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  352: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  353: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  354: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  355: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  356: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  357: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  358: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  359: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  360: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  361: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  362: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  363: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  364: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 6 stored elements in Compressed Sparse Row format>,
#  365: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  366: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  367: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  368: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  369: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  370: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  371: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  372: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  373: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  374: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  376: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  377: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  378: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  379: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  380: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 5 stored elements in Compressed Sparse Row format>,
#  381: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  382: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  383: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  384: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  385: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  386: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  387: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  388: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  389: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  390: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  391: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  393: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  405: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  406: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  407: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  408: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  409: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  410: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  412: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  413: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  414: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  415: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  416: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  417: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  418: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  419: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  420: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  421: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  422: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  423: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  424: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  425: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  426: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  427: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  428: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  429: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  430: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  431: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  432: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  433: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  434: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  435: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  436: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  437: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  438: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  440: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  441: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  442: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  444: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  445: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  446: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  448: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  449: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  450: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  451: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  452: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  453: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  454: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  455: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  456: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  457: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  458: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  459: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 6 stored elements in Compressed Sparse Row format>,
#  460: <1x20 sparse matrix of type '<class 'numpy.float64'>'
# ...
#  1147: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  1148: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  1150: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  1151: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  1156: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  1161: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  1162: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  1163: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  1167: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  1170: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  1171: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  1172: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  1173: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  1175: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  1176: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  1177: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  1178: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  1179: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  1180: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  1183: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  1184: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  1185: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  1186: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  1187: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  1188: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  1189: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  1190: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  1191: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  1192: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  1193: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  1194: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  1196: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  1197: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 5 stored elements in Compressed Sparse Row format>,
#  1198: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  1199: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  1200: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  1201: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  1202: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  1203: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  1204: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  1206: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  1207: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  1208: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  1209: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  1210: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  1211: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  1212: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  1213: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  1214: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  1215: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 5 stored elements in Compressed Sparse Row format>,
#  1216: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  1217: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  1218: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  1219: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  1220: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  1221: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  1222: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  1223: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 5 stored elements in Compressed Sparse Row format>,
#  1224: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  1225: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  1226: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  1227: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  1228: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  1230: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  1231: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  1232: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  1233: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  1234: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  1235: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  1236: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  1237: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  1238: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  1240: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  1241: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  1242: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  1243: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  1244: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  1245: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  1246: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  1247: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  1248: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  1249: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  1250: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  1251: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  1252: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  1253: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  1254: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  1255: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  1256: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  1257: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  1258: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  1259: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  1260: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  1261: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  1262: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  1263: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  1264: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 5 stored elements in Compressed Sparse Row format>,
#  1265: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  1266: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  1267: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  1268: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  1269: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  1270: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  1271: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  1272: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  1273: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  1274: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  1275: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  1276: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  1277: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  1278: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  1279: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  1280: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  1281: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  1282: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  1283: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  1284: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  1285: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  1286: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  1287: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  1288: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  1289: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  1290: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  1291: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  1292: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  1293: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  1295: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  1296: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  1297: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1 stored elements in Compressed Sparse Row format>,
#  1298: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  1299: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  1300: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  1301: <1x20 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  ...}

# %%
tags_doc = {}
for uniq in tags.movieId.unique():
    tags_doc[uniq] = ''.join(' '.join(tags[tags['movieId'] == uniq]['tag']).lower())

# %%
tags_doc
# Out:
# {60756: 'funny highly quotable will ferrell comedy funny will ferrell funny will ferrell',
#  89774: 'boxing story mma tom hardy',
#  106782: 'drugs leonardo dicaprio martin scorsese stock market wall street',
#  48516: 'way too long leonardo dicaprio suspense twist ending undercover cop atmospheric jack nicholson leonardo dicaprio martin scorsese suspense',
#  431: 'al pacino gangster mafia',
#  1221: 'al pacino mafia mafia',
#  5995: 'holocaust true story holocaust',
#  44665: 'twist ending',
#  52604: 'anthony hopkins courtroom drama twist ending',
#  88094: 'britpop indie record label music',
#  144210: 'dumpster diving sustainability',
#  1569: 'romantic comedy wedding weddings',
#  118985: 'painter',
#  119141: 'bloody bromance comedy funny james franco seth rogen',
#  109487: 'black hole sci-fi time-travel christopher nolan sci-fi time-travel bad dialogue philosophical issues thought-provoking visually appealing',
#  2: 'fantasy magic board game robin williams game',
#  110: 'beautiful scenery epic historical inspirational medieval mel gibson oscar (best cinematography) revenge sword fight scotland',
#  410: 'black comedy christina ricci christopher lloyd dark comedy family gothic',
#  2023: 'al pacino andy garcia classic francis ford coppola mafia',
#  2124: 'black comedy christina ricci christopher lloyd family gothic quirky',
#  2953: 'family funny macaulay culkin sequel',
#  3114: 'animation disney funny original pixar sequel tom hanks pixar',
#  3578: 'ancient rome epic history imdb top 250 revenge rome russell crowe romans',
#  4223: 'ed harris jude law rachel weisz sniper world war ii',
#  5388: 'al pacino atmospheric hilary swank robin williams atmospheric insomnia thought-provoking',
#  6058: 'sequel violent',
#  6534: 'dogs eric bana mad scientist marvel',
#  6541: 'captain nemo comic book gothic peta wilson sean connery superhero',
#  6564: 'adventure angelina jolie heroine in tight suit',
#  7153: 'adventure ensemble cast fantasy fantasy world great soundtrack lord of the rings scenic stylized tolkien tolkein',
#  8641: 'hilarious steve carell will ferrell stupid awesome comedy will ferrell',
#  27660: 'animation anime cyberpunk dark matrix sci-fi',
#  27706: 'dark comedy jim carrey meryl streep quirky stylized',
#  27808: 'adam sandler family sweet',
#  27831: 'british gangster confusing daniel craig exquisite plotting. organized crime stylish tom hardy',
#  31658: 'anime fantasy world hayao miyazaki studio ghibli 06 oscar nominated best movie - animation in netflix queue',
#  33162: 'david thewlis eva green liam neeson orlando bloom',
#  34150: 'chris evans comic book heroine in tight suit jessica alba sexy female scientist superhero',
#  37729: 'gothic helena bonham carter johnny depp tim burton visually appealing animation 06 oscar nominated best movie - animation',
#  38061: 'black comedy clever fast-paced dialogue good dialogue robert downey jr. witty in netflix queue',
#  45447: 'adventure audrey tautou conspiracy theory mystery paris tom hanks treasure hunt',
#  46723: 'brad pitt cate blanchett multiple storylines social commentary',
#  46972: 'ben stiller robin williams',
#  46976: 'emma thompson maggie gyllenhaal modern fantasy romance surreal will ferrell',
#  49130: 'marion cotillard',
#  49530: 'africa corruption jennifer connelly justice leonardo dicaprio',
#  53464: 'bad acting bad jokes bad plot chris evans jessica alba marvel sexy female scientist',
#  58047: 'rachel weisz ryan reynolds',
#  59501: 'fantasy lion narnia tilda swinton',
#  60074: 'bad script charlize theron will smith',
#  60126: 'anne hathaway steve carell',
#  61024: 'comedy james franco seth rogen stoner movie',
#  63992: 'audience intelligence underestimated boring chick flick overrated teen movie',
#  68848: 'adrien brody con artists funny interesting characters mark ruffalo rachel weisz',
#  71535: 'bill murray dark comedy emma stone funny jesse eisenberg woody harrelson',
#  87430: 'audience intelligence underestimated cgi cheesy comic book dc dc comics ryan reynolds space superhero',
#  88405: 'comedy funny happy ending hot actress justin timberlake mila kunis new york city romance sex',
#  96861: 'istanbul liam neeson predictable turkey unnecessary sequel',
#  99114: 'action christoph waltz funny good soundtrack great performances humour leonardo dicaprio quentin tarantino samuel l. jackson soundtrack western soundtrack',
#  103042: 'amy adams superhero',
#  104863: 'daniel radcliffe zoe kazan',
#  107348: 'comedy steve carell stupid but funny will ferrell',
#  108190: 'anti-intellectual bad writing dystopia new society plot holes predictable scifi unintelligent',
#  111743: 'charlize theron liam neeson seth macfarlane witty',
#  114180: 'action dystopia plot holes post-apocalyptic survival thriller unexplained weak plot',
#  115149: 'dark hero gun-fu keanu reeves revenge secret society stylish action killer widows/widowers',
#  116897: 'black comedy dark comedy dark humor ironic multiple short stories short stories',
#  122912: 'comic book dr. strange great villain guardians of the galaxy marvel mcu robert downey jr. thanos thor visually stunning dark emotional sad visually appealing visually stunning',
#  128360: 'characters dialogue humor kurt russell quentin tarantino samuel l. jackson tension building violent western',
#  135133: 'dystopia jennifer lawrence love story nonsense politics rebellion revolution',
#  135518: 'ben kingsley ethics immortality ryan reynolds',
#  135536: "bad story bad writing batman ben affleck comic book dc comics good soundtrack harley quinn harley quinn's ass horrible directing jared leto joker lack of plot margot robbie poor story poorly paced superhero visually appealing will smith",
#  136864: 'action batman ben affleck dark dc comics gal gadot superhero superman wonderwoman',
#  139385: 'leonardo dicarpio survival tom hardy visually appealing cinematography visually appealing visually striking',
#  158966: 'building a family creative freedom good writing individualism viggo mortensen',
#  168248: 'action dark hero gun tactics hitman keanu reeves organized crime secret society heroic bloodshed',
#  174053: 'dystopia future interesting jon hamm thought provoking',
#  179401: 'action comedy dwayne johnson funny',
#  183611: 'comedy funny rachel mcadams',
#  184471: 'adventure alicia vikander video game adaptation',
#  187593: 'josh brolin ryan reynolds sarcasm',
#  187595: 'emilia clarke star wars',
#  260: 'classic space action action sci-fi epic great soundtrack classic sci-fi engrossing adventure epic classic nerd classic sci-fi space action space epic oldie but goodie sci-fi star wars robots and androids space classic sci-fi sci-fi space adventure star wars darth vader luke skywalker space opera',
#  296: "good dialogue great soundtrack non-linear cult film drugs quentin tarantino tarantino hit men 1990s achronological action action packed aggressive amazing amazing dialogues anthology assassin atmospheric awesome bad ass bad language bad-ass bible biblical references big boys with guns big name actors black comedy black humor black humour blood blood splatters bloody bruce willis brutality casual violence character development characters classic classic movie coke comedy conversation cool cool style crime crime scene scrubbing cult cult classic cult film dance dancing dark dark comedy dark humor dialogue different diner disjointed timeline disturbing drama drug overdose drugs drugs & music ensemble cast entertaining entirely dialogue episodic exciting fast paced fast-paced film noir film-noir foul language fun funny gangster gangsters genius golden watch good dialogue good music gore great acting great dialogue great soundtrack gritty guns harvey keitel heroin highly quotable hit men hitman homosexuality humour iconic imdb top 250 innovative intellectual intelligent intense interesting intertwining storylines interwoven storylines ironic irony john travolta killer-as-protagonist los angeles mafia masterpiece meaningless violence milkshake mobster mobsters monologue motherfucker multiple stories multiple storylines neo-noir noir non-linear non-linear timeline nonlinear nonlinear narrative nonlinear storyline nonlinear timeline notable soundtrack offensive organised crime organized crime original original plot out of order palme d'or parody philosophical pop culture references psychological pulp quentin tarantino quirky quotable r:disturbing violent content including rape r:disturbing violent images r:graphic sexuality r:some violence r:strong bloody violence r:strong language r:sustained strong stylized violence r:violence random rape retro roger avary royal with cheese samuel l. jackson sarcasm satire sexy smart writing sophisticated soundtrack splatter steve buscemi storytelling stylish stylized suspense tarantino thought-provoking thriller travolta twist ending uma thurman unique unpredictable unusual very funny violence violent witty",
#  4896: 'everything you want is here alan rickman harry potter humorous magic magic wizards',
#  106489: 'adventure fantasy tolkien too long',
#  101142: 'animation funny stone age',
#  115617: 'animation kids robots feel-good fun family movie very funny',
#  120635: 'action murder police',
#  1726: 'kevin costner post apocalyptic',
#  2387: 'dark comedy dark humor',
#  3052: 'irreverent jay and silent bob kevin smith satire religion',
#  5088: 'irreverent',
#  7022: 'based on a book bloody brutal controversial dystopia goretastic satire social commentary survival violence',
#  7254: 'alternate reality sci-fi science fiction time travel',
#  8957: 'brutal clever disturbing great ending mindfuck surprise ending suspense',
#  9010: 'cruel characters',
#  42632: 'brutality',
#  58301: 'dark humor dark dark humor intelligent thought-provoking',
#  60950: 'threesome',
#  62434: 'seth rogen sexual humor',
#  67695: 'seth rogen',
#  100083: 'embarassing scenes offensive r language sarcasm satire',
#  156371: "80's",
#  158872: 'crude humor mindfuck sarcasm satire vulgar',
#  3556: 'sofia coppola 1970s suicide',
#  6323: 'john cusack',
#  6367: 'ewan mcgregor renee zellweger retro',
#  59103: 'jackie chan kung fu',
#  52287: 'something for everyone in this one... saw it without and plan on seeing it with kids!',
#  293: 'assassin jean reno hit men action assassin assassination assassins awkward romance corruption crime disturbing drama french friendship gary oldman great acting guns hit men hitman humorous imdb top 250 jean reno lolita theme loneliness love story luc besson natalie portman organized crime police police corruption quirky sniper tense touching unique',
#  54286: 'assassin assassin-in-training (scene) espionage robert ludlum',
#  104: 'test tag golf adam sandler',
#  2579: 'black and white christopher nolan directorial debut mindfuck not linear twist ending black and white',
#  3793: 'action comic book hugh jackman marvel superhero superhero',
#  4226: 'dark mindfuck nonlinear psychology twist ending mystery psychological twist ending backwards. memory mystery twist ending cerebral dreamlike',
#  6283: 'amazing artwork anime sci-fi',
#  27156: 'anime end of the world epic mecha psychology',
#  193565: 'anime comedy gintama remaster',
#  4878: 'atmospheric cult film dreamlike hallucinatory psychological surreal time travel jake gyllenhaal time travel dreamlike hallucinatory mental illness psychology social commentary teen thought-provoking atmospheric cerebral dreamlike enigmatic hallucinatory mental illness mindfuck philosophy psychological quirky surreal thought-provoking weird',
#  7147: 'dreamlike sentimental surreal tim burton',
#  7361: 'alternate reality memory thought-provoking jim carrey memory cult film imagination jim carrey love surreal arthouse artistic atmospheric beautiful bittersweet colourful comedy dreamlike emotional feel-good happpiness humane insightful intelligent lovely melancholy mind-bending philosophy quirky quirky romantic romantic surreal surrealism thought-provoking',
#  97938: 'cinematography india surreal',
#  6938: 'big wave surfing',
#  48780: 'ummarti2006 atmospheric enigmatic',
#  126548: 'funny high school',
#  68319: 'comic book bad plot comic book hugh jackman ryan reynolds too many characters',
#  7020: 'notable nudity',
#  3: 'moldy old',
#  527: 'moving thought-provoking holocaust based on a true story biography disturbing holocaust',
#  1101: 'predictable navy',
#  50872: 'a clever chef rat inspirational clever inspirational',
#  102007: 'animation',
#  118696: 'hope',
#  6711: 'atmospheric japan',
#  4034: 'drugs based on a tv show',
#  4995: 'mathematics',
#  6502: 'zombies zombies',
#  6953: 'depressing',
#  34405: 'predictable firefly',
#  55721: 'favelas',
#  83134: 'black comedy',
#  778: 'based on a book dark comedy narrated drug abuse',
#  4612: 'reciprocal spectator',
#  4708: 'reciprocal spectator',
#  6400: 'documentary crime',
#  30892: 'animation documentary henry darger',
#  48698: 'the catholic church is the most corrupt organization in history',
#  64034: 'childish naivity friendship',
#  68954: 'adventure bechdel test:fail cartoon children computer animation divorce dogs dreams pixar bittersweet emotional heartbreaking touching',
#  71494: 'narrative pisstake',
#  81158: 'american idolatry',
#  82459: 'atmospheric coen brothers jeff bridges matt damon predictable',
#  90769: 'celebrity fetishism mediacentralism system holism',
#  96084: 'city politics italy political right versus left',
#  111364: 'creature feature',
#  118784: 'documentary music industry remix culture',
#  127172: 'film history poetic representation of children',
#  364: 'disney disney animated feature oscar (best music - original score) soundtrack disney',
#  1288: 'music heavy metal mockumentary music',
#  1923: 'ben stiller ben stiller crude humor goofy',
#  2616: 'comic book',
#  3481: 'music nick hornby',
#  3897: 'music journalism music rolling stone',
#  51255: 'british comedy',
#  1: 'pixar pixar fun',
#  153: 'superhero superhero',
#  552: 'knights',
#  1246: 'highschool high school',
#  32587: 'cult',
#  33660: 'boksdrama boxing',
#  34162: 'stiller',
#  36529: 'wapendrama',
#  38798: 'sisters',
#  2146: 'post-college',
#  37384: 'restaurant',
#  40955: 'transvestite',
#  44889: 'satire',
#  61323: 'dark comedy brad pitt coen bros coen brothers dark comedy espionage george clooney john malkovich satire twists & turns weird',
#  39: 'chick flick funny paul rudd quotable seen more than once emma jane austen',
#  1059: 'amazing cinematography leonardo dicaprio shakespeare updated classics shakespeare',
#  2762: 'atmospheric bruce willis ghosts imdb top 250 mindfuck stylized twist ending ghosts i see dead people',
#  4370: 'android(s)/cyborg(s) artificial intelligence bittersweet steven spielberg robots',
#  5464: 'cinematography tom hanks',
#  7078: 'bette davis oscar (best actress)',
#  7444: 'mark ruffalo',
#  7451: 'clever high school lesbian subtext high school',
#  54997: 'christian bale',
#  55290: 'casey affleck great performances twist',
#  91500: 'ending',
#  91529: 'anne hathaway christian bale christopher nolan comic book great ending morgan freeman political commentary superhero',
#  98961: 'afghanistan american propaganda assassination military terrorism',
#  32: 'time travel time travel brad pitt bruce willis mindfuck post apocalyptic post-apocalyptic remake time travel twist ending',
#  47: 'mystery twist ending serial killer',
#  50: 'mindfuck suspense thriller tricky twist ending heist',
#  147: 'addiction heroin leonardo dicaprio mark wahlberg',
#  175: 'controversial new york city nudity (full frontal)',
#  223: 'cynical hilarious independent film quirky witty generation x',
#  288: 'brutality controversial dark comedy psychedelic satire stylized',
#  541: 'sci-fi robots androids artificial intelligence atmospheric cyberpunk future mindfuck philip k. dick atmospheric dreamlike existentialism philosophical',
#  589: 'apocalypse arnold schwarzenegger nuclear war sci-fi suspense time travel robots scifi masterpiece',
#  608: 'based on a true story dark comedy kidnapping steve buscemi coen brothers',
#  628: 'edward norton psychology suspense thought-provoking twist ending priest',
#  1089: 'ensemble cast nonlinear quentin tarantino stylized heist violence humorous neo-noir quentin tarantino religion tarantino',
#  1120: 'freedom of expression',
#  1136: 'british comedy monty python england king arthur',
#  1193: 'emotional jack nicholson mental illness',
#  1198: 'adventure archaeology indiana jones steven spielberg treasure hunt archaeology ark of the covenant indiana jones',
#  1200: 'action aliens horror sci-fi space space craft space travel suspense space',
#  1219: 'alfred hitchcock psychology suspenseful tense norman bates alfred hitchcock black and white imdb top 250 remade',
#  1240: 'action artificial intelligence robots sci-fi special effects tense time travel robots',
#  1258: 'atmospheric disturbing horror jack nicholson masterpiece psychological stanley kubrick suspense stephen king',
#  1343: 'horror juliette lewis martin scorsese robert de niro remake',
#  1625: 'mindfuck mystery plot twist psychological suspense twist ending twist ending mystery',
#  1704: 'inspirational heartwarming inspirational',
#  1921: 'hallucinatory mental illness mindfuck paranoid mathematics artsy atmospheric cerebral enigmatic existentialism hallucinatory insanity paranoia paranoid surreal tense visually appealing',
#  2160: 'atmospheric creepy paranoia scary suspense demons',
#  2296: 'snl',
#  2329: 'thought-provoking racism edward norton emotional politics',
#  2505: 'nicolas cage',
#  2571: 'martial arts sci-fi alternate universe philosophy post apocalyptic',
#  2700: 'adult humor controversial crude humor free speech parody satire south park trey parker',
#  2959: 'dark comedy psychology thought-provoking twist ending dark comedy violence action atmospheric based on a book brad pitt challenging chuck palahniuk classic clever complicated consumerism crime dark dark comedy david fincher disturbing double life edward norton fighting great acting helena bonham carter imaginary friend imdb top 250 mental illness mind-blowing mindfuck narrated nudity (topless) palahnuik philosophical philosophy postmodern powerful ending psychological psychological thriller psychology quirky satirical schizophrenia social commentary societal criticism stylized surreal terrorism thought-provoking twist twist ending violence violent',
#  3176: 'based on a book creepy disturbing jude law murder obsession psychology secrets serial killer suspense europe murder',
#  3186: 'asylum based on a true story brittany murphy mental hospital psychology winona ryder',
#  3499: 'claustrophobic horror scary stephen king suspenseful tense thriller',
#  3527: 'aliens sci-fi scifi cult aliens arnold schwarzenegger dialogue guns jesse ventura macho sci-fi scifi cult',
#  3911: 'satire dogs',
#  3948: 'comedy robert de niro',
#  4262: 'al pacino',
#  4816: 'ben stiller comedy david bowie goofy mindless one liners will ferrell',
#  4993: 'fantasy high fantasy magic mythology tolkien wizards tolkein',
#  5291: 'black and white samurai in netflix queue samurai',
#  6016: 'multiple storylines true story crime photography violence not seen',
#  6188: 'comedy will ferrell',
#  6290: 'rob zombie',
#  8950: 'christian bale creepy powerful ending psychology schizophrenia twist ending psychology',
#  27020: 'drugs lesbian',
#  30825: 'ben stiller robert de niro',
#  34323: 'rob zombie',
#  40278: 'jake gyllenhaal modern war',
#  53127: 'based on a play conspiracy theory creepy insanity paranoia ptsd',
#  66097: 'claymation creepy dark dark fairy tale surreal tim burton',
#  68157: 'black comedy brad pitt christoph waltz quentin tarantino satire',
#  74458: 'insanity leonardo dicaprio martin scorsese plot twist psychological psychological thriller thought-provoking',
#  79132: 'action alternate reality leonardo dicaprio sci-fi thought-provoking visually appealing dreamlike surreal visually appealing big budget clever complicated dead wife great soundtrack heist intellectual mindfuck philosophy psychological psychology suspense thought-provoking cerebral dreamlike philosophy thought-provoking',
#  81562: 'stranded',
#  81591: 'alter ego atmospheric creepy horror obsession surreal',
#  102903: 'illusions overcomplicated predictable stupid ending',
#  104879: 'absorbing acting atmospheric hugh jackman jake gyllenhaal morality mystery thriller',
#  106100: 'jared leto social commentary uplifting',
#  112515: 'atmospheric dark metaphorical psychological',
#  112556: 'annoying stupid ending',
#  750: 'dark comedy atomic bomb black comedy dark comedy satire purity of essence slim pickens black comedy dark comedy quirky',
#  58559: 'psychology superhero dark gritty',
#  5952: 'myth tolkein',
#  98809: 'action myth',
#  152711: 'cambodia crime human rights murder procedural',
#  5: 'pregnancy remake',
#  7: 'remake',
#  11: 'politics president',
#  14: 'politics president',
#  16: 'mafia',
#  17: 'jane austen',
#  21: 'hollywood',
#  22: 'serial killer',
#  25: 'alcoholism',
#  26: 'shakespeare',
#  28: 'in netflix queue jane austen',
#  29: 'kidnapping',
#  31: 'high school teacher',
#  34: 'animal movie pigs villain nonexistent or not needed for good story',
#  36: 'death penalty nun',
#  38: 'twins',
#  40: 'in netflix queue south africa',
#  41: 'shakespeare',
#  43: 'england',
#  45: 'journalism',
#  46: 'wedding',
#  52: 'adoption prostitution',
#  58: 'writing',
#  62: 'music',
#  92: 'jekyll and hyde',
#  96: 'theater',
#  101: 'crime off-beat comedy quirky',
#  107: 'muppets',
#  111: 'assassination',
#  116: 'holocaust',
#  122: 'dating',
#  140: 'journalism',
#  150: 'moon nasa space',
#  160: 'michael crichton',
#  161: 'submarine',
#  162: 'in netflix queue',
#  185: 'computers',
#  199: 'made me cry',
#  215: 'generation x',
#  216: 'school adam sandler stop looking at me swan',
#  222: 'ireland',
#  224: 'mental illness psychology',
#  230: 'stephen king',
#  232: 'in netflix queue',
#  235: 'movie business',
#  237: 'basketball france infertility',
#  246: 'basketball',
#  247: 'australia',
#  249: 'beethoven',
#  252: 'einstein',
#  257: 'court',
#  261: 'louisa may alcott',
#  262: 'england girl power india',
#  272: 'england mental illness',
#  277: 'christmas',
#  279: 'in netflix queue',
#  280: 'prison',
#  282: 'disability twins',
#  290: 'in netflix queue',
#  300: 'tv',
#  307: 'death',
#  308: 'marriage cynical',
#  316: 'time travel',
#  317: 'christmas',
#  318: 'prison stephen king wrongful imprisonment morgan freeman',
#  326: 'in netflix queue',
#  329: 'enterprise',
#  337: 'mental illness',
#  338: 'serial killer',
#  339: 'coma',
#  342: 'australia weddings',
#  345: 'cross dressing men in drag remade',
#  349: 'tom clancy',
#  350: 'john grisham',
#  351: 'interracial romance',
#  356: 'shrimp vietnam bubba gump shrimp lieutenant dan stupid is as stupid does bittersweet emotional heartwarming touching',
#  357: 'wedding',
#  361: 'gambling',
#  363: 'holocaust in netflix queue',
#  371: 'journalism',
#  377: 'bus',
#  380: 'spies',
#  381: 'alcoholism',
#  412: 'edith wharton',
#  421: 'horses',
#  425: 'mental illness oscar (best actress)',
#  440: 'president',
#  454: 'john grisham',
#  457: 'based on a tv show',
#  471: 'hula hoop',
#  474: 'assassination',
#  475: 'ireland',
#  477: 'biopic',
#  480: 'dinosaur',
#  488: 'japan sexuality',
#  497: 'shakespeare',
#  500: 'cross dressing divorce men in drag',
#  508: 'aids',
#  513: 'radio show business',
#  515: 'butler housekeeper',
#  516: 'military',
#  522: 'australia racism violence',
#  524: 'football',
#  529: 'chess',
#  531: 'in netflix queue',
#  534: 'c.s. lewis',
#  535: 'large cast',
#  538: 'race',
#  539: 'empire state building',
#  543: 'beat poetry',
#  551: 'christmas halloween',
#  556: 'politics',
#  562: 'adolescence',
#  586: 'christmas',
#  587: 'overrated',
#  588: 'disney',
#  590: 'american indians native americans',
#  592: 'superhero',
#  593: 'hannibal lector disturbing drama gothic psychology suspense',
#  594: 'disney',
#  595: 'disney',
#  596: 'disney',
#  597: 'prostitution',
#  616: 'disney',
#  638: 'babies',
#  647: 'gulf war',
#  648: 'based on a tv show',
#  668: 'india',
#  670: 'india',
#  671: 'spoof',
#  673: 'bugs bunny',
#  708: 'veterinarian',
#  720: 'aardman',
#  728: 'in netflix queue',
#  733: 'alcatraz michael bay terrorism',
#  736: 'disaster',
#  745: 'aardman',
#  748: 'aliens',
#  780: 'aliens',
#  800: 'in netflix queue',
#  805: 'john grisham',
#  818: 'based on a tv show',
#  830: 'adultery',
#  832: 'kidnapping give me back my son! it was melodramatic and kind of dumb mel gibson',
#  838: 'jane austen',
#  852: 'golf',
#  858: 'mafia',
#  892: 'shakespeare',
#  898: 'divorce',
#  899: 'movie business',
#  900: 'france',
#  902: 'capote',
#  903: 'falling alfred hitchcock atmospheric imdb top 250 james stewart',
#  904: 'voyeurism imdb top 250 james stewart mystery photographer photography',
#  905: 'screwball',
#  906: 'brooch',
#  907: 'divorce',
#  908: 'mount rushmore alfred hitchcock imdb top 250',
#  909: 'adultery',
#  910: 'men in drag',
#  911: 'heist',
#  912: 'start of a beautiful friendship',
#  913: 'statue',
#  914: 'george bernard shaw',
#  915: 'rich guy - poor girl',
#  916: 'italy royalty',
#  918: '1900s',
#  919: 'dorothy toto',
#  920: 'civil war',
#  921: 'television',
#  922: 'movies eerie movie business',
#  923: 'rosebud',
#  924: 'hal space aliens apes arthur c. clarke artificial intelligence atmospheric cinematography classic computer confusing ending cult film dull future futuristic imdb top 250 masterpiece meditative music mystery oscar (best effects - visual effects) overrated philosophical relaxing revolutionary robots sci-fi setting:space/space ship slow slow paced soundtrack space space travel spacecraft stanley kubrick superb soundtrack surreal technology tedious visual visually appealing',
#  926: 'hollywood',
#  927: 'divorce',
#  928: 'mrs. dewinter',
#  929: 'europe journalism war',
#  930: 'assassination',
#  931: 'amnesia',
#  934: 'wedding',
#  936: 'cold war russia',
#  938: 'prostitution',
#  940: 'swashbuckler',
#  941: 'swashbuckler',
#  943: 'ghosts',
#  944: 'shangri-la',
#  945: 'astaire and rogers',
#  947: 'butler homeless screwball',
#  948: 'oil',
#  950: 'nick and nora charles',
#  951: 'screwball',
#  952: 'race',
#  953: 'christmas',
#  954: 'politics',
#  955: 'leopard screwball',
#  956: 'adoption',
#  965: 'fugitive',
#  968: 'zombies',
#  969: 'missionary',
#  970: 'crime',
#  971: 'tennessee williams',
#  973: 'journalism',
#  976: 'hemingway',
#  986: 'animal movie',
#  991: 'ireland',
#  994: 'food',
#  1006: 'death penalty john grisham',
#  1010: 'disney race',
#  1013: 'twins',
#  1022: 'disney',
#  1025: 'disney king arthur',
#  1028: 'disney nanny',
#  1029: 'disney',
#  1030: 'disney',
#  1032: 'disney',
#  1033: 'disney',
#  1035: 'rogers and hammerstein',
#  1041: 'in netflix queue',
#  1042: 'music',
#  1066: 'astaire and rogers',
#  1068: 'anti-semitism',
#  1076: 'governess',
#  1079: 'fish',
#  1080: 'bible parody religion',
#  1081: 'cross dressing',
#  1082: 'politics',
#  1084: '1920s gangsters',
#  1088: 'dance music',
#  1090: 'vietnam',
#  1093: '1960s jim morrison music',
#  1096: 'holocaust',
#  1097: 'aliens',
#  1103: '1950s adolescence',
#  1104: 'tennessee williams',
#  1124: 'aging',
#  1125: 'clousseau',
#  1135: 'military',
#  1147: 'boxing in netflix queue',
#  1148: 'aardman',
#  1171: 'politics',
#  1177: 'italy',
#  1178: 'court military',
#  1179: 'crime',
#  1183: 'adultery',
#  1185: 'in netflix queue',
#  1187: 'disability',
#  1188: 'australia dance',
#  1189: 'in netflix queue police',
#  1196: 'i am your father space space opera classic george lucas harrison ford music original plot sci-fi sequel',
#  1197: 'inigo montoya six-fingered man',
#  1201: 'spaghetti western',
#  1203: 'court claustrophobic confrontational earnest good dialogue great screenplay gritty motivational thought-provoking',
#  1204: 'middle east',
#  1206: 'brainwashing',
#  1207: 'harper lee racism',
#  1208: 'vietnam',
#  1209: 'spaghetti western',
#  1210: 'darth vader luke skywalker space opera',
#  1212: 'ferris wheel venice zither',
#  1213: 'mafia',
#  1214: 'aliens',
#  1217: 'samurai',
#  1220: 'saturday night live',
#  1222: 'vietnam anti-war',
#  1223: 'moon',
#  1224: 'shakespeare',
#  1225: 'mozart salieri',
#  1228: 'boxing',
#  1230: 'new york',
#  1231: 'nasa space',
#  1233: 'submarine',
#  1234: 'the entertainer',
#  1235: 'may-december romance',
#  1237: 'chess death atmospheric cerebral existentialism philosophical reflective',
#  1242: 'civil war',
#  1243: 'shakespeare sort of',
#  1244: 'black and white',
#  1245: 'mafia',
#  1247: 'simon and garfunkel',
#  1249: 'hit men',
#  1250: 'pow',
#  1252: 'incest',
#  1253: 'aliens',
#  1254: 'cold',
#  1257: 'skiing',
#  1259: 'stephen king',
#  1260: 'serial killer atmospheric chilly creepy menacing mental illness oninous',
#  1262: 'pow',
#  1263: 'vietnam',
#  1266: 'revenge',
#  1267: 'assassination brainwashing',
#  1269: 'murder',
#  1270: 'time travel',
#  1272: 'world war ii',
#  1276: 'prison',
#  1277: 'in netflix queue',
#  1278: 'spoof',
#  1280: 'in netflix queue',
#  1281: 'nazis',
#  1282: 'disney',
#  1283: 'gunfight',
#  1284: 'hammett',
#  1285: 'high school',
#  1291: 'archaeology holy grail',
#  1292: 'television',
#  1293: 'india',
#  1296: 'e. m. forster',
#  1299: 'cambodia vietnam',
#  1301: 'shakespeare sort of space',
#  1302: 'baseball',
#  1303: 'india',
#  1304: 'crime',
#  1307: 'new york',
#  1333: 'birds',
#  1344: 'lawyer',
#  1345: 'high school prom stephen king',
#  1348: 'vampires',
#  1350: 'demons',
#  1353: 'personals ads',
#  1354: 'religion',
#  1356: 'borg',
#  1358: 'ex-con',
#  1361: 'in netflix queue',
#  1363: 'religion',
#  1366: 'arthur miller',
#  1367: 'dogs remake',
#  1372: 'klingons',
#  1374: 'captain kirk',
#  1376: 'whales',
#  1377: 'superhero',
#  1380: 'high school',
#  1381: 'high school',
#  1387: 'shark',
#  1389: 'shark',
#  1393: 'sports',
#  1394: 'coen brothers',
#  1396: 'spying',
#  1398: 'hemingway',
#  1407: 'slasher spoof',
#  1408: 'hawkeye james fennimore cooper',
#  1411: 'shakespeare',
#  1413: 'conan',
#  1416: 'andrew lloyd weber',
#  1423: 'in netflix queue vietnam',
#  1441: 'mental illness not seen',
#  1446: 'in netflix queue',
#  1449: 'mockumentary',
#  1466: 'mafia',
#  1474: 'jungle',
#  1485: 'lawyer',
#  1496: 'tolstoy',
#  1500: 'hit men reunion',
#  1513: 'reunion',
#  1537: 'ballroom dance',
#  1542: 'in netflix queue',
#  1544: 'dinosaurs',
#  1545: 'death',
#  1573: 'transplants',
#  1580: 'aliens',
#  1586: 'military',
#  1608: 'president',
#  1610: 'tom clancy',
#  1617: 'police',
#  1635: '1970s',
#  1643: 'england queen victoria',
#  1645: 'lawyers',
#  1650: 'henry james',
#  1653: 'future intelligent thought-provoking',
#  1663: 'military',
#  1672: 'in netflix queue',
#  1674: 'amish',
#  1680: 'alternate universe',
#  1682: 'tv',
#  1683: 'henry james',
#  1711: 'savannah',
#  1717: 'sequel slasher spoof',
#  1719: 'canada death',
#  1721: 'shipwreck romance',
#  1732: 'coen brothers black comedy bowling classic coen brothers comedy crime cult classic cult film dark comedy deadpan drugs funny great dialogue great soundtrack highly quotable imdb top 250 jeff bridges john goodman julianne moore kidnapping marijuana nudity (full frontal) off-beat comedy philip seymour hoffman quirky ransom rug sarcasm satirical steve buscemi violence',
#  1735: 'charles dickens',
#  1748: 'amnesia',
#  1777: '1980s',
#  1797: 'in netflix queue',
#  1810: 'politics',
#  1834: 'twist ending',
#  1836: 'no dvd at netflix',
#  1893: 'in netflix queue',
#  1900: 'in netflix queue',
#  1902: 'generation x',
#  1909: 'conspiracy',
#  1912: 'heist',
#  1913: 'australia',
#  1917: 'space',
#  1931: 'ships',
#  1938: 'alcoholism',
#  1940: 'anti-semitism judaism',
#  1942: 'huey long in netflix queue robert penn warren',
#  1945: 'boxing coulda been a contender',
#  1947: 'gangs',
#  1950: 'racism',
#  1951: 'dickens',
#  1952: 'prostitution',
#  1953: 'drugs police',
#  1954: 'boxing sports',
#  1955: 'divorce',
#  1957: 'olympics sports',
#  1959: 'adultery africa',
#  1960: 'china',
#  1961: 'autism',
#  1962: 'rasicm',
#  1975: 'jason',
#  1976: 'jason',
#  1977: 'jason',
#  1978: 'jason',
#  1979: 'jason',
#  1983: 'halloween',
#  1984: 'halloween',
#  1994: 'ghosts',
#  1995: 'ghosts',
#  1996: 'ghosts',
#  1997: 'demons',
#  2006: 'california mexico',
#  2011: 'time travel',
#  2019: 'samurai',
#  2020: 'adultery',
#  2022: 'bible katzanzakis',
#  2028: 'world war ii',
#  2054: 'disney',
#  2058: 'police',
#  2059: 'twins',
#  2064: 'general motors michigan',
#  2065: 'in netflix queue',
#  2066: 'memory',
#  2070: 'music',
#  2071: 'aids in netflix queue',
#  2076: 'sexuality suburbia',
#  2078: 'disney',
#  2080: 'disney',
#  2085: 'disney',
#  2097: 'carnival ray bradbury',
#  2100: 'mermaid',
#  2108: 'weather forecaster',
#  2114: 's.e. hinton',
#  2115: 'archaeology',
#  2116: 'tolkein classic',
#  2118: 'stephen king',
#  2121: 'stephen king',
#  2122: 'stephen king',
#  2139: 'mice',
#  2145: '1980s high school',
#  2167: 'vampires',
#  2171: 'aquarium boston personals ads',
#  2186: 'murder',
#  2187: 'theater',
#  2194: 'capone gangsters',
#  2202: 'survival',
#  2203: 'small towns',
#  2206: 'paranoia',
#  2208: 'train',
#  2243: 'journalism',
#  2247: 'mafia',
#  2248: 'in your eyes lloyd dobbler',
#  2249: 'mafia',
#  2268: 'court military',
#  2291: 'freaks',
#  2295: 'screwball',
#  2300: 'broadway',
#  2302: 'court',
#  2310: 'adolescence',
#  2312: 'death penalty',
#  2313: 'freaks',
#  2324: 'holocaust bittersweet emotional heartwarming poignant sentimental tear jerker tearjerking',
#  2334: 'terrorism',
#  2335: 'football',
#  2336: 'england',
#  2351: 'in netflix queue',
#  2355: 'pixar',
#  2357: 'south america',
#  2360: 'in netflix queue',
#  2390: 'in netflix queue',
#  2391: 'heist',
#  2394: 'bible moses',
#  2396: 'england',
#  2410: 'boxing',
#  2411: 'boxing',
#  2412: 'boxing',
#  2420: 'martial arts',
#  2421: 'martial arts',
#  2422: 'martial arts',
#  2423: 'christmas',
#  2424: 'e-mail remake',
#  2431: 'doctors bad',
#  2442: 'in netflix queue',
#  2463: 'kidnapping',
#  2467: 'religion',
#  2470: 'australia',
#  2471: 'australia',
#  2491: 'food',
#  2494: 'holocaust hungary',
#  2502: 'stapler workplace',
#  2506: 'disability',
#  2517: 'stephen king',
#  2529: 'twist ending',
#  2550: 'ghosts',
#  2553: 'evil children',
#  2554: 'evil children',
#  2565: 'siam',
#  2572: 'shakespeare sort of',
#  2581: 'high school',
#  2583: 'southern us',
#  2598: 'golfing',
#  2600: 'virtual reality',
#  2612: 'motherhood',
#  2628: 'prequel the force',
#  2640: 'superhero',
#  2641: 'superhero',
#  2642: 'superhero',
#  2648: 'in netflix queue',
#  2660: 'aliens',
#  2664: '1950s',
#  2677: 'in netflix queue',
#  2692: 'alternate endings',
#  2693: 'star trek',
#  2699: 'spiders',
#  2710: 'claims to be true video',
#  2712: 'sexuality',
#  2716: 'ghosts',
#  2717: 'ghosts',
#  2719: 'remake',
#  2723: 'superhero',
#  2726: 'heist',
#  2728: 'crucifixion rome slavery',
#  2745: 'missionary priest',
#  2750: 'nostalgia radio',
#  2761: 'robots animation',
#  2787: 'stephen king',
#  2791: 'aviation spoof',
#  2797: 'children',
#  2801: 'gambling',
#  2803: 'lawyers',
#  2804: 'christmas',
#  2827: 'aliens',
#  2863: 'beatles',
#  2871: 'river',
#  2872: 'england king arthur',
#  2905: 'in netflix queue',
#  2915: 'prostitution',
#  2918: 'high school',
#  2919: 'academy award (best supporting actress) indonesia journalism',
#  2927: 'adultery',
#  2935: 'gambling',
#  2937: 'screwball',
#  2939: 'in netflix queue',
#  2940: 'nightclub',
#  2941: 'island',
#  2943: 'vietnam',
#  2952: 'gambling',
#  2966: 'brothers lawn mower',
#  2967: 'evil children',
#  2968: 'time travel',
#  2987: 'live action/animation',
#  3000: 'anime adventure atmospheric fantasy world studio ghibli surreal',
#  3006: 'tobacco true story',
#  3007: 'in netflix queue',
#  3011: 'dance marathon',
#  3028: 'shakespeare',
#  3030: 'samurai',
#  3039: 'class dan aykroyd',
#  3040: 'camp',
#  3044: 'memory music',
#  3060: 'in netflix queue',
#  3071: 'high school',
#  3072: 'new york',
#  3077: 'in netflix queue up series',
#  3081: 'ichabod crane',
#  3087: 'christmas new york',
#  3095: 'depression dust bowl',
#  3097: 'remade',
#  3098: 'baseball sports',
#  3101: 'adultery',
#  3108: 'homeless',
#  3111: 'racism',
#  3115: 'men in drag',
#  3125: 'graham greene',
#  3135: 'fatherhood',
#  3147: 'stephen king',
#  3152: 'black-and-white',
#  3160: 'l.a.',
#  3174: 'andy kaufman',
#  3175: 'spoof',
#  3178: 'boxing',
#  3181: 'shakespeare',
#  3192: 'in netflix queue',
#  3210: 'high school',
#  3211: 'a dingo ate my baby australia',
#  3247: 'nuns',
#  3250: 'in netflix queue',
#  3258: 'plastic surgery',
#  3259: 'ireland',
#  3260: 'e.m. forster',
#  3263: 'basketball',
#  3270: 'figure skating',
#  3273: 'slasher spoof',
#  3281: 'sexuality',
#  3306: 'big top circus',
#  3307: 'blind',
#  3310: 'orphans',
#  3317: 'writing',
#  3330: 'adolescence sexuality',
#  3338: 'in netflix queue',
#  3341: 'remade',
#  3360: 'basketball',
#  3384: 'subway',
#  3385: 'peace corp',
#  3386: 'politics president',
#  3408: 'scandal true story',
#  3420: 'lawyers',
#  3421: 'college toga',
#  3424: 'racism great cinematography',
#  3429: 'aardman',
#  3435: 'insurance',
#  3447: 'pearl s buck',
#  3451: 'hepburn and tracy interracial marriage prejudice racism',
#  3456: 'in netflix queue',
#  3461: 'island',
#  3462: 'factory',
#  3468: 'pool',
#  3469: 'court evolution religion',
#  3475: 'class',
#  3489: 'peter pan',
#  3498: 'in netflix queue',
#  3502: 'death',
#  3504: 'journalism',
#  3507: 'in netflix queue',
#  3512: 'transplants',
#  3515: 'alternate endings',
#  3526: 'families',
#  3528: 'psychiatrist',
#  3536: 'priest rabbi',
#  3546: 'show business',
#  3548: '1920s',
#  3549: 'gambling',
#  3552: 'golf',
#  3559: 'in netflix queue',
#  3566: 'business religion',
#  3608: 'pee wee herman',
#  3629: 'mining',
#  3675: 'christmas',
#  3676: 'in netflix queue art house atmospheric creepy cryptic dark disturbing dreamlike enigmatic fucked up gruesome hallucinatory insane paranoid strange surreal weird',
#  3683: 'coen brothers',
#  3712: 'television',
#  3723: 'shakespeare',
#  3724: 'vietnam',
#  3730: 'spying',
#  3735: 'police',
#  3801: 'court',
#  3811: 'court',
#  3816: 'missing children',
#  3844: 'diabetes',
#  3849: 'disability',
#  3859: 'in netflix queue televangelist',
#  3877: 'superhero',
#  3910: 'blindness factory',
#  3932: 'invisibility',
#  3949: 'drug abuse depressing psychology',
#  3951: 'in netflix queue',
#  3967: 'ballet',
#  3983: 'family',
#  3988: 'dr. seuss',
#  3994: 'superhero atmospheric comics father-son relationship mindfuck unique atmospheric somber',
#  3996: 'china martial arts',
#  4007: 'business',
#  4012: 'stand-up comedy',
#  4019: 'writing',
#  4024: 'edith wharton',
#  4025: 'pageant',
#  4027: 'bluegrass',
#  4029: 'movies',
#  4046: 'quakers',
#  4077: 'psychopaths',
#  4105: 'zombies',
#  4113: 'tennessee williams',
#  4117: 'in netflix queue',
#  4138: 'demons',
#  4160: 'death penalty',
#  4164: 'homeless new york',
#  4166: 'reality tv',
#  4171: "eugene o'neill",
#  4174: 'in netflix queue',
#  4184: 'christmas',
#  4189: 'bible religion',
#  4190: 'preacher religion',
#  4191: 'sexuality',
#  4194: 'in netflix queue',
#  4204: 'virginity',
#  4210: 'hannibal lecter serial killer',
#  4211: 'von bulow',
#  4214: 'college',
#  4218: 'in netflix queue',
#  4221: 'football',
#  4232: 'spying',
#  4246: 'singletons',
#  4259: 'nabokov',
#  4263: 'alcoholism',
#  4292: 'union',
#  4296: 'death',
#  4306: 'fairy tales',
#  4312: 'in netflix queue',
#  4316: 'figure skating',
#  4326: 'race rasicm',
#  4333: 'strangers on a train',
#  4347: 'holocaust',
#  4356: 'in netflix queue',
#  4359: 'adultery',
#  4361: 'men in drag',
#  4380: 'accident',
#  4396: 'race',
#  4404: 'in netflix queue',
#  4447: 'lawyers',
#  4448: 'heist boring',
#  4465: 'rape',
#  4476: 'twins',
#  4477: 'circus',
#  4489: 'africa immigrants',
#  4495: 'new york',
#  4526: 'aliens',
#  4537: 'hippies',
#  4545: 'robots',
#  4546: 'kidnapping remade',
#  4558: 'twins',
#  4571: 'time travel',
#  4600: 'doctors',
#  4621: 'babies',
#  4623: 'baseball',
#  4638: 'dinosaurs',
#  4639: 'hollywood movie business',
#  4641: 'adolescence',
#  4677: 'dogs',
#  4678: 'television',
#  4688: 'in netflix queue',
#  4787: 'prodigies',
#  4801: 'family',
#  ...}

# %%
tags_count = CountVectorizer()
X_train_tags_vec = tags_count.fit_transform(tags_doc.values())
tfidf_tags = TfidfTransformer()
X_tags_train_tfidf = tfidf_tags.fit_transform(X_train_tags_vec)

# %%
print(X_tags_train_tfidf.shape, X_train_tfidf.shape)
# Out:
# (1572, 1744) (9742, 20)

# %%
ratings['rating'].unique()
# Out:
# array([4. , 5. , 3. , 2. , 1. , 4.5, 3.5, 2.5, 0.5, 1.5])

# %%
from sklearn.neighbors import NearestNeighbors

# %%
neigh = NearestNeighbors(n_neighbors=5, n_jobs=-1, metric='euclidean') 
neigh.fit(X_train_tfidf)
neigh_tag = NearestNeighbors(n_neighbors=5, n_jobs=-1, metric='euclidean')
neigh_tag.fit(X_tags_train_tfidf)
# Out:
# NearestNeighbors(metric='euclidean', n_jobs=-1)

# %%
X_tags_train_tfidf[0]
# Out:
# <1x1744 sparse matrix of type '<class 'numpy.float64'>'
# 	with 6 stored elements in Compressed Sparse Row format>

# %%
ratings[(ratings['movieId']==5)&(ratings['userId']==1)]['rating'].isnull
# Out:
# <bound method Series.isnull of Series([], Name: rating, dtype: float64)>

# %%
def find_rating(MovieId, UserId):
    mean_mov = np.sum(ratings[ratings['movieId']==MovieId]['rating'])
    user_rating = np.sum(ratings[(ratings['movieId']==MovieId)&(ratings['userId']==UserId)]['rating'])
    if ((user_rating==0)&(mean_mov!=0.)):
        mean_mov = (mean_mov+user_rating)/(len(ratings[ratings['movieId']==MovieId]['rating'])+
                                           len(ratings[(ratings['movieId']==MovieId)&(ratings['userId']==UserId)]['rating']))
    elif(mean_mov!=0.):
        mean_mov = (0.2*mean_mov+0.8*user_rating)/(len(ratings[ratings['movieId']==MovieId]['rating'])+
                                           len(ratings[(ratings['movieId']==MovieId)&(ratings['userId']==UserId)]['rating']))
    if (mean_mov - int(mean_mov)>=0.5):
        return np.round(mean_mov)
    elif ((mean_mov - int(mean_mov)<0.5)&(mean_mov - int(mean_mov)>=0.25)):
        return int(mean_mov)+0.5
    else:
        return int(mean_mov)

# %%
data = {'tags_near_1':[],
       'tags_near_2':[],
       'tags_near_3':[],
       'tags_near_4':[],
       'tags_near_5':[],
       'genres_near_1':[],
       'genres_near_2':[],
       'genres_near_3':[],
       'genres_near_4':[],
       'genres_near_5':[],
       'user':[]}
for i in tqdm_notebook(range(0,len(ratings['rating']))):
    for key in (data.keys()):
        if (key[0]=='t'):
            if (tags_doc.get(ratings['movieId'][i])==None):
                data.get(key).append(np.NaN)
            else:
                data.get(key).append(find_rating(ratings['userId'][i], ratings['movieId'][neigh_tag.kneighbors(
                    tfidf_tags.transform(tags_count.transform(
                     [tags_doc.get(ratings['movieId'][i])])))[1][0][int(key[-1])-1]]))
        elif (key[0]=='g'):
            data.get(key).append(find_rating(ratings['userId'][i], ratings['movieId'][neigh.kneighbors(
            genres_dict.get(ratings['movieId'][i]))[1][0][int(key[-1])-1]]))
        else:
            data.get(key).append(ratings['userId'][i])
# Out:
# /var/folders/ll/sf8djrcj0ljd5cltbywtgm9w0000gn/T/ipykernel_9977/2448717633.py:12: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm_notebook(range(0,len(ratings['rating']))):
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
data['userId'] = data.pop('user')
near_df = pd.DataFrame(data = data )

# %%
near_df.head()
# Out:
#    tags_near_1  tags_near_2  tags_near_3  tags_near_4  tags_near_5  \
# 0          4.0          4.0          4.0          4.0          4.0
# 1          4.0          4.0          4.0          4.0          4.0
# 2          NaN          NaN          NaN          NaN          NaN
# 3          4.0          4.0          4.0          4.0          4.0
# 4          4.0          4.0          4.0          4.0          4.0
#
#    genres_near_1  genres_near_2  genres_near_3  genres_near_4  genres_near_5  \
# 0            1.0            4.0            4.0            4.0            4.0
# 1            4.0            4.0            4.0            4.0            4.0
# 2            4.0            4.0            4.0            4.0            4.0
# 3            4.0            4.0            4.0            4.0            4.0
# 4            4.0            4.0            4.0            4.0            4.0
#
#    userId
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
del(ratings['timestamp'])

# %%
rec_df = ratings.merge(near_df,how = 'outer', on='userId')

# %%
rec_df.head()
# Out:
#    userId  movieId  rating  tags_near_1  tags_near_2  tags_near_3  \
# 0       1        1     4.0          4.0          4.0          4.0
# 1       1        1     4.0          4.0          4.0          4.0
# 2       1        1     4.0          NaN          NaN          NaN
# 3       1        1     4.0          4.0          4.0          4.0
# 4       1        1     4.0          4.0          4.0          4.0
#
#    tags_near_4  tags_near_5  genres_near_1  genres_near_2  genres_near_3  \
# 0          4.0          4.0            1.0            4.0            4.0
# 1          4.0          4.0            4.0            4.0            4.0
# 2          NaN          NaN            4.0            4.0            4.0
# 3          4.0          4.0            4.0            4.0            4.0
# 4          4.0          4.0            4.0            4.0            4.0
#
#    genres_near_4  genres_near_5
# 0            4.0            4.0
# 1            4.0            4.0
# 2            4.0            4.0
# 3            4.0            4.0
# 4            4.0            4.0

# %%
rec_df.dropna(inplace=True)

# %%
from sklearn.model_selection import train_test_split

# %%
Y = rec_df['rating']
X = rec_df
del(X['rating'])
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = .2)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
reg = RandomForestRegressor()
reg.fit(X_train, Y_train)
mean_squared_error(reg.predict(X_test),Y_test)
# Out:
# 0.00017077294272660376

# %%
reg.score(X_test,Y_test)
# Out:
# 0.9998420634390862
